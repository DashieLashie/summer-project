# %%
import pandas as pd
import numpy as np
from transformers import pipeline

# %%
import torch
device = torch.device("cuda")

# %%
tweets_df = pd.read_parquet("stock_tweets_withsentiment_nomerge")
tweets_df
# Out:
#        ticker                                               text  \
# 0        AAPL  summary of yesterdays webcast featuringwynn  g...
# 1        AAPL  summary of yesterdays webcast featuringwynn  g...
# 2        AAPL                          itv will boost appleapple
# 3        AAPL  iphone users are more intelligent than samsung...
# 4        AAPL  summary of yesterdays webcast featuringwynn  g...
# ...       ...                                                ...
# 106333    XOM  divest fromstopcommoncore optout because child...
# 106334    XOM  fslr first solaryldfslr  gprodia fslr stocks s...
# 106335    XOM   nptn recent news updated tuesday  december   ...
# 106336    XOM  zsl stock forumzslgold  uslv zsl investing nasdaq
# 106337    XOM  exxon mobils buy rating reiterated at morningstar
#
#                       created_at     user_id        date  sentiment
# 0      2014-01-01 03:59:03+00:00  1938270918  2014-01-01          4
# 1      2014-01-01 03:29:29+00:00  1933063572  2014-01-01          4
# 2      2014-01-01 18:08:47+00:00    23059499  2014-01-01          5
# 3      2014-01-01 01:52:31+00:00    23954327  2014-01-01          5
# 4      2014-01-01 01:18:36+00:00  1937591882  2014-01-01          4
# ...                          ...         ...         ...        ...
# 106333 2015-12-28 19:39:46+00:00  4399710563  2015-12-28          1
# 106334 2015-12-28 02:54:00+00:00    19221345  2015-12-28          5
# 106335 2015-12-29 19:03:17+00:00  2197054086  2015-12-29          1
# 106336 2015-12-29 16:52:36+00:00  2181314366  2015-12-29          5
# 106337 2015-12-30 06:17:34+00:00   992182100  2015-12-30          5
#
# [106338 rows x 6 columns]

# %%
classifier = pipeline("text-classification", model="j-hartmann/emotion-english-distilroberta-base", return_all_scores=True)
# Out:
# Device set to use cuda:0
# /opt/miniconda3/lib/python3.10/site-packages/transformers/pipelines/text_classification.py:106: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(

# %%
test = classifier("This is so exciting!")[0]

# %%
test
# Out:
# [{'label': 'anger', 'score': 0.005241709761321545},
#  {'label': 'disgust', 'score': 0.0013800495071336627},
#  {'label': 'fear', 'score': 0.0029143476858735085},
#  {'label': 'joy', 'score': 0.8689908981323242},
#  {'label': 'neutral', 'score': 0.023466892540454865},
#  {'label': 'sadness', 'score': 0.0025007547810673714},
#  {'label': 'surprise', 'score': 0.09550537168979645}]

# %%
def emotion_analysis(text):
    analysis = classifier(text)[0]
    scores_list= []
    for emotion in analysis:
        scores_list.append(emotion['score'])

    return scores_list

# %%
emotion_analysis("This is so exciting!")
# Out:
# [0.005241709761321545,
#  0.0013800495071336627,
#  0.0029143476858735085,
#  0.8689908981323242,
#  0.023466892540454865,
#  0.0025007547810673714,
#  0.09550537168979645]

# %%
tweets_df[['emotion_anger', 'emotion_disgust', 'emotion_fear', 'emotion_joy', 'emotion_neutral', 'emotion_sadness', 'emotion_surprize']] = tweets_df['text'].apply(emotion_analysis).apply(pd.Series)
# Out:
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset

# %%
tweets_df
# Out:
#        ticker                                               text  \
# 0        AAPL  summary of yesterdays webcast featuringwynn  g...
# 1        AAPL  summary of yesterdays webcast featuringwynn  g...
# 2        AAPL                          itv will boost appleapple
# 3        AAPL  iphone users are more intelligent than samsung...
# 4        AAPL  summary of yesterdays webcast featuringwynn  g...
# ...       ...                                                ...
# 106333    XOM  divest fromstopcommoncore optout because child...
# 106334    XOM  fslr first solaryldfslr  gprodia fslr stocks s...
# 106335    XOM   nptn recent news updated tuesday  december   ...
# 106336    XOM  zsl stock forumzslgold  uslv zsl investing nasdaq
# 106337    XOM  exxon mobils buy rating reiterated at morningstar
#
#                       created_at     user_id        date  sentiment  \
# 0      2014-01-01 03:59:03+00:00  1938270918  2014-01-01          4
# 1      2014-01-01 03:29:29+00:00  1933063572  2014-01-01          4
# 2      2014-01-01 18:08:47+00:00    23059499  2014-01-01          5
# 3      2014-01-01 01:52:31+00:00    23954327  2014-01-01          5
# 4      2014-01-01 01:18:36+00:00  1937591882  2014-01-01          4
# ...                          ...         ...         ...        ...
# 106333 2015-12-28 19:39:46+00:00  4399710563  2015-12-28          1
# 106334 2015-12-28 02:54:00+00:00    19221345  2015-12-28          5
# 106335 2015-12-29 19:03:17+00:00  2197054086  2015-12-29          1
# 106336 2015-12-29 16:52:36+00:00  2181314366  2015-12-29          5
# 106337 2015-12-30 06:17:34+00:00   992182100  2015-12-30          5
#
#         emotion_anger  emotion_disgust  emotion_fear  emotion_joy  \
# 0            0.004113         0.000816      0.002997     0.109428
# 1            0.004113         0.000816      0.002997     0.109428
# 2            0.009720         0.001733      0.002435     0.324003
# 3            0.003730         0.001393      0.002404     0.043920
# 4            0.004113         0.000816      0.002997     0.109428
# ...               ...              ...           ...          ...
# 106333       0.010287         0.004786      0.004878     0.024959
# 106334       0.014853         0.002200      0.058870     0.134360
# 106335       0.003425         0.000886      0.003080     0.183165
# 106336       0.008301         0.001208      0.015512     0.139979
# 106337       0.047200         0.001639      0.020053     0.070970
#
#         emotion_neutral  emotion_sadness  emotion_surprize
# 0              0.642936         0.032780          0.206931
# 1              0.642936         0.032780          0.206931
# 2              0.447821         0.018303          0.195984
# 3              0.579827         0.022491          0.346236
# 4              0.642936         0.032780          0.206931
# ...                 ...              ...               ...
# 106333         0.676030         0.089251          0.189808
# 106334         0.312550         0.102926          0.374241
# 106335         0.167113         0.163263          0.479069
# 106336         0.484214         0.089062          0.261724
# 106337         0.796823         0.011534          0.051782
#
# [106338 rows x 13 columns]

# %%
tweets_df.to_parquet('stock_tweets_withsentiment_withemotion_nomerge',index=False)
